# %%
import sqlite3 as sql
import pandas as pd

# %%
con = sql.connect("spotify.sqlite")
con.text_factory = lambda b: b.decode(errors = 'ignore')
df = pd.read_sql_query("SELECT * from tracks", con)
df_genres = pd.read_sql_query("SELECT * from genres", con)
df_a_features = pd.read_sql_query("SELECT * from audio_features", con)
con.close()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8741672 entries, 0 to 8741671
# Data columns (total 10 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   id                object
#  1   disc_number       int64
#  2   duration          int64
#  3   explicit          int64
#  4   audio_feature_id  object
#  5   name              object
#  6   preview_url       object
#  7   track_number      int64
#  8   popularity        int64
#  9   is_playable       float64
# dtypes: float64(1), int64(5), object(4)
# memory usage: 666.9+ MB

# %%
df.tail()
# Out:
#                              id  disc_number  duration  explicit  \
# 8741667  12S1TA13KXl13sCQZgtI5y            1    198000         0
# 8741668  134MLEMX0AWp5kbMMf90f8            1    191360         0
# 8741669  13WVJaMn0ztUCU8UFCKQFO            1    272572         0
# 8741670  11SfAvTgnEEYy4Ef0fyFpE            1    237200         1
# 8741671  13EW51DKru044OJDJ9Bm8o            1    153147         1
#
#                audio_feature_id  \
# 8741667  12S1TA13KXl13sCQZgtI5y
# 8741668  134MLEMX0AWp5kbMMf90f8
# 8741669  13WVJaMn0ztUCU8UFCKQFO
# 8741670  11SfAvTgnEEYy4Ef0fyFpE
# 8741671  13EW51DKru044OJDJ9Bm8o
#
#                                                       name  \
# 8741667                                   Dime (Unplugged)
# 8741668                                 You Done Fucked Up
# 8741669  Again (ASOT 770) [Future Favorite] - Andrew Ra...
# 8741670                                 Sound Is Vibration
# 8741671  TRAGIC (feat. Youngboy Never Broke Again & Int...
#
# ...

# %%
df.loc[df['id'] == '1dizvxctg9dHEyaYTFufVi']
# Out:
#                        id  disc_number  duration  explicit  \
# 0  1dizvxctg9dHEyaYTFufVi            1    275893         1
#
#          audio_feature_id                                   name preview_url  \
# 0  1dizvxctg9dHEyaYTFufVi  Gz And Hustlas (feat. Nancy Fletcher)
#
#    track_number  popularity  is_playable
# 0            12           0          NaN

# %%
df_a_features.head()
# Out:
#                        id  acousticness  \
# 0  2jKoVlU7VAmExKJ1Jh3w9P        0.1800
# 1  4JYUDRtPZuVNi7FAnbHyux        0.2720
# 2  6YjKAkDYmlasMqYw73iB0w        0.0783
# 3  2YlvHjDb4Tyxl4A1IcDhAe        0.5840
# 4  3UOuBNEin5peSRqdzvlnWM        0.1700
#
#                                         analysis_url  danceability  duration  \
# 0  https://api.spotify.com/v1/audio-analysis/2jKo...         0.893    219160
# 1  https://api.spotify.com/v1/audio-analysis/4JYU...         0.520    302013
# 2  https://api.spotify.com/v1/audio-analysis/6YjK...         0.918    288200
# 3  https://api.spotify.com/v1/audio-analysis/2Ylv...         0.877    243013
# 4  https://api.spotify.com/v1/audio-analysis/3UOu...         0.814    270667
#
#    energy  instrumentalness  key  liveness  loudness  mode  speechiness  \
# 0   0.514          0.000000   11    0.0596    -5.080     1        0.283
# 1   0.847          0.000000    9    0.3250    -5.300     1        0.427
# ...

# %%
df_genres.head()
# Out:
#                  id
# 0   detroit hip hop
# 1            g funk
# 2      gangster rap
# 3  hardcore hip hop
# 4           hip hop

# %%
df_a_features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8740043 entries, 0 to 8740042
# Data columns (total 15 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   id                object
#  1   acousticness      float64
#  2   analysis_url      object
#  3   danceability      float64
#  4   duration          int64
#  5   energy            float64
#  6   instrumentalness  float64
#  7   key               int64
#  8   liveness          float64
#  9   loudness          float64
#  10  mode              int64
#  11  speechiness       float64
#  12  tempo             float64
#  13  time_signature    int64
#  14  valence           float64
# dtypes: float64(9), int64(4), object(2)
# memory usage: 1000.2+ MB

# %%
df_a_features.loc[df_a_features['id'] == '1dizvxctg9dHEyaYTFufVi']
# Out:
#                         id  acousticness  \
# 19  1dizvxctg9dHEyaYTFufVi         0.164
#
#                                          analysis_url  danceability  duration  \
# 19  https://api.spotify.com/v1/audio-analysis/1diz...         0.652    275893
#
#     energy  instrumentalness  key  liveness  loudness  mode  speechiness  \
# 19   0.814               0.0    1      0.36    -4.901     1         0.31
#
#      tempo  time_signature  valence
# 19  91.888               4    0.788

# %%
df_t_f=df
df_t_f['valence'] = df_t_f.id.map(df_a_features.set_index('id')['valence'])
df_t_f['acousticness'] = df_t_f.id.map(df_a_features.set_index('id')['acousticness'])

# %%
df_t_f.head()
# Out:
#                        id  disc_number  duration  explicit  \
# 0  1dizvxctg9dHEyaYTFufVi            1    275893         1
# 1  2g8HN35AnVGIk7B8yMucww            1    252746         1
# 2  49pnyECzcMGCKAqxfTB4JZ            3    315080         0
# 3  4E5IFAXCob6QqZaJMTw5YN            1    240800         1
# 4  1gSt2UlC7mtRtJIc5zqKWn            2    203666         0
#
#          audio_feature_id                                               name  \
# 0  1dizvxctg9dHEyaYTFufVi              Gz And Hustlas (feat. Nancy Fletcher)
# 1  2g8HN35AnVGIk7B8yMucww                          Big Poppa - 2005 Remaster
# 2  49pnyECzcMGCKAqxfTB4JZ  You Were Born - Early Version Of "One Of The T...
# 3  4E5IFAXCob6QqZaJMTw5YN                                Poppin' Them Thangs
# 4  1gSt2UlC7mtRtJIc5zqKWn              It's Hard To Say "I Do", When I Don't
#
#                                          preview_url  track_number  \
# 0                                                               12
# ...

# %%
df_t_f.loc[df['id'] == '1dizvxctg9dHEyaYTFufVi']
# Out:
#                        id  disc_number  duration  explicit  \
# 0  1dizvxctg9dHEyaYTFufVi            1    275893         1
#
#          audio_feature_id                                   name preview_url  \
# 0  1dizvxctg9dHEyaYTFufVi  Gz And Hustlas (feat. Nancy Fletcher)
#
#    track_number  popularity  is_playable  valence  acousticness
# 0            12           0          NaN    0.788         0.164
